# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('data/train.csv')

# %%
metaphor_words = {0:'road', 1:'candle', 2: 'light', 3: 'spice', 4: 'ride', 5: 'train', 6: 'boat'}

# %%
data.shape
# Out:
# (1870, 3)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       metaphorID  label_boolean  \
# 0              0           True
# 1              2          False
# 2              2          False
# 3              4          False
# 4              2          False
# ...          ...            ...
# 1865           4           True
# 1866           4           True
# 1867           0           True
# 1868           5           True
# 1869           2           True
#
#                                                    text
# 0     Hey , Karen !!!! I was told that on the day of...
# 1     Hi Ladies ... my last chemo was Feb 17/09 , ra...
# 2     I have just come form my consult with a lovely...
# 3     I also still question taking Tamox for stage 1...
# 4     Just checking in to say hello ladies . I had a...
# ...                                                 ...
# 1865  Hi there . I found my lump 3 weeks ago and it ...
# 1866  Robyn-Sorry you find yourself on this web site...
# 1867  I 'm happy Jule that you posted this question ...
# 1868  Hiya April RADs-I should probably have been he...
# 1869  thanks for the hugs , and the prayers , meece ...
#
# [1870 rows x 3 columns]>

# %%
data.head()
# Out:
#    metaphorID  label_boolean  \
# 0           0           True
# 1           2          False
# 2           2          False
# 3           4          False
# 4           2          False
#
#                                                 text
# 0  Hey , Karen !!!! I was told that on the day of...
# 1  Hi Ladies ... my last chemo was Feb 17/09 , ra...
# 2  I have just come form my consult with a lovely...
# 3  I also still question taking Tamox for stage 1...
# 4  Just checking in to say hello ladies . I had a...

# %%
positive_label_data = data[data['label_boolean'] == True]
negative_label_data = data[data['label_boolean'] == False]

# %%
positive_label_data
# Out:
#       metaphorID  label_boolean  \
# 0              0           True
# 5              2           True
# 7              0           True
# 8              6           True
# 9              0           True
# ...          ...            ...
# 1865           4           True
# 1866           4           True
# 1867           0           True
# 1868           5           True
# 1869           2           True
#
#                                                    text
# 0     Hey , Karen !!!! I was told that on the day of...
# 5     How is everyone doing ? I 'm 10 weeks post op ...
# 7     I had a bilateral mastecomy in June followed b...
# 8     Just diagnosed late November . Stage I and wit...
# 9     swimangel172 , With regard to my comments I di...
# ...                                                 ...
# 1865  Hi there . I found my lump 3 weeks ago and it ...
# 1866  Robyn-Sorry you find yourself on this web site...
# 1867  I 'm happy Jule that you posted this question ...
# 1868  Hiya April RADs-I should probably have been he...
# 1869  thanks for the hugs , and the prayers , meece ...
#
# [1432 rows x 3 columns]

# %%
negative_label_data
# Out:
#       metaphorID  label_boolean  \
# 1              2          False
# 2              2          False
# 3              4          False
# 4              2          False
# 6              2          False
# ...          ...            ...
# 1826           0          False
# 1842           3          False
# 1856           4          False
# 1861           2          False
# 1862           4          False
#
#                                                    text
# 1     Hi Ladies ... my last chemo was Feb 17/09 , ra...
# 2     I have just come form my consult with a lovely...
# 3     I also still question taking Tamox for stage 1...
# 4     Just checking in to say hello ladies . I had a...
# 6     Hello Jodi , It 's going to be OK . I just had...
# ...                                                 ...
# 1826  My oncologist did n't make any reference to th...
# 1842  Hello All I just finished 4 rounds of AC and 1...
# 1856  Good Morning Jewels , SheShe-We must have post...
# 1861  I had a mastectomy in Aug 09 , Stage2 , Grade ...
# 1862  JDH - like those above , do n't be mad at Mom ...
#
# [438 rows x 3 columns]

# %%
vectorizer = CountVectorizer(stop_words='english', max_features=1000)

# %%
X = vectorizer.fit_transform(data['text'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, data['label_boolean'], test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.7967914438502673
# Precision: 0.8284
# Recall: 0.9127
# F1 Score: 0.8685

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Accuracy: 0.8181818181818182
# Precision: 0.8819
# Recall: 0.8691
# F1 Score: 0.8755

# %%
data['word'] = data['metaphorID'].map(metaphor_words)
